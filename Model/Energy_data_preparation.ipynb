# %%
import numpy as np
import pandas as pd
import os
import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df_consumption = pd.read_csv(r"C:\Users\kanch\Energy price prediction\Energy price prediction\Energy_data\Actual_consumption_201901010000_202501010000_Hour.csv", delimiter=";", encoding="utf-8").reset_index()
df_actual_consumption = df_consumption .copy()

# %%
df_generation = pd.read_csv(r"C:\Users\kanch\Energy price prediction\Energy price prediction\Energy_data\Actual_generation_201901010000_202501010000_Hour.csv", delimiter=";", encoding="utf-8").reset_index()
df_actual_generation = df_generation.copy()

# %%
df_prices = pd.read_csv(r"C:\Users\kanch\Energy price prediction\Energy price prediction\Energy_data\Day-ahead_prices_201901010000_202501010000_Hour.csv", delimiter=";", encoding="utf-8").reset_index()
df_day_ahead_prices = df_prices.copy()

# %%
df_energy = df_actual_consumption.merge(df_actual_generation, on='index').merge(df_day_ahead_prices, on='index')
energy = df_energy.copy()

# %%
df_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52608 entries, 0 to 52607
# Data columns (total 40 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   index                                                              52608 non-null  int64
#  1   Start date_x                                                       52608 non-null  object
#  2   End date_x                                                         52608 non-null  object
#  3   grid load [MWh] Calculated resolutions                             52608 non-null  object
#  4   Grid load incl. hydro pumped storage [MWh] Calculated resolutions  52608 non-null  object
#  5   Hydro pumped storage [MWh] Calculated resolutions_x                52608 non-null  object
#  6   Residual load [MWh] Calculated resolutions                         52608 non-null  object
# ...

# %% [markdown]
# # DROP UNNECESSARY COLUMNS

# %%
energy.columns
# Out:
# Index(['index', 'Start date_x', 'End date_x',
#        'grid load [MWh] Calculated resolutions',
#        'Grid load incl. hydro pumped storage [MWh] Calculated resolutions',
#        'Hydro pumped storage [MWh] Calculated resolutions_x',
#        'Residual load [MWh] Calculated resolutions', 'Start date_y',
#        'End date_y', 'Biomass [MWh] Calculated resolutions',
#        'Hydropower [MWh] Calculated resolutions',
#        'Wind offshore [MWh] Calculated resolutions',
#        'Wind onshore [MWh] Calculated resolutions',
#        'Photovoltaics [MWh] Calculated resolutions',
#        'Other renewable [MWh] Calculated resolutions',
#        'Nuclear [MWh] Calculated resolutions',
#        'Lignite [MWh] Calculated resolutions',
#        'Hard coal [MWh] Calculated resolutions',
#        'Fossil gas [MWh] Calculated resolutions',
#        'Hydro pumped storage [MWh] Calculated resolutions_y',
#        'Other conventional [MWh] Calculated resolutions', 'Start date',
# ...

# %%
energy = energy.drop(['∅ DE/LU neighbours [€/MWh] Original resolutions',
       'Belgium [€/MWh] Original resolutions',
       'Denmark 1 [€/MWh] Original resolutions',
       'Denmark 2 [€/MWh] Original resolutions',
       'France [€/MWh] Original resolutions',
       'Netherlands [€/MWh] Original resolutions',
       'Norway 2 [€/MWh] Original resolutions',
       'Austria [€/MWh] Original resolutions',
       'Poland [€/MWh] Original resolutions',
       'Sweden 4 [€/MWh] Original resolutions',
       'Switzerland [€/MWh] Original resolutions',
       'Czech Republic [€/MWh] Original resolutions',
       'DE/AT/LU [€/MWh] Original resolutions',
       'Northern Italy [€/MWh] Calculated resolutions',
       'Slovenia [€/MWh] Original resolutions',
       'Hungary [€/MWh] Original resolutions','Start date','Nuclear [MWh] Calculated resolutions',
       'End date', 'Start date_y',
       'End date_y','End date_x'], axis=1)

# %%
energy.head()
# Out:
#    index          Start date_x grid load [MWh] Calculated resolutions  \
# 0      0  Jan 1, 2019 12:00 AM                              43,273.75
# 1      1   Jan 1, 2019 1:00 AM                              41,631.25
# 2      2   Jan 1, 2019 2:00 AM                              40,085.00
# 3      3   Jan 1, 2019 3:00 AM                              39,269.75
# 4      4   Jan 1, 2019 4:00 AM                              39,032.75
#
#   Grid load incl. hydro pumped storage [MWh] Calculated resolutions  \
# 0                                          44,546.75
# 1                                          43,042.00
# 2                                          42,561.75
# 3                                          42,554.25
# 4                                          42,748.50
#
#   Hydro pumped storage [MWh] Calculated resolutions_x  \
# 0                                           1,273.00
# 1                                           1,410.75
# ...

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52608 entries, 0 to 52607
# Data columns (total 18 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   index                                                              52608 non-null  int64
#  1   Start date_x                                                       52608 non-null  object
#  2   grid load [MWh] Calculated resolutions                             52608 non-null  object
#  3   Grid load incl. hydro pumped storage [MWh] Calculated resolutions  52608 non-null  object
#  4   Hydro pumped storage [MWh] Calculated resolutions_x                52608 non-null  object
#  5   Residual load [MWh] Calculated resolutions                         52608 non-null  object
#  6   Biomass [MWh] Calculated resolutions                               52608 non-null  object
# ...

# %%
energy['Start date_x'] = pd.to_datetime(energy['Start date_x'])

for i in energy.columns:
    if energy[i].dtypes=="object":
        energy[i] = pd.to_numeric(energy[i].str.replace(',', ''), errors='coerce')

# %%
energy = energy.rename(columns={'Start date_x': 'MESS_DATUM'})

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52608 entries, 0 to 52607
# Data columns (total 18 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   index                                                              52608 non-null  int64
#  1   MESS_DATUM                                                         52608 non-null  datetime64[ns]
#  2   grid load [MWh] Calculated resolutions                             52608 non-null  float64
#  3   Grid load incl. hydro pumped storage [MWh] Calculated resolutions  52608 non-null  float64
#  4   Hydro pumped storage [MWh] Calculated resolutions_x                52608 non-null  float64
#  5   Residual load [MWh] Calculated resolutions                         52608 non-null  float64
#  6   Biomass [MWh] Calculated resolutions                               52608 non-null  float64
# ...

# %%
# Save the DataFrame to a CSV file
energy.to_csv(r"C:\Users\kanch\Energy price prediction\Energy price prediction\FINAL DATA FOR EDA\cleaned_energy_data.csv", index=False)

# %%
energy.describe()
# Out:
#               index                     MESS_DATUM  \
# count  52608.000000                          52608
# mean   26303.500000  2022-01-01 00:05:03.832116480
# min        0.000000            2019-01-01 00:00:00
# 25%    13151.750000            2020-07-02 00:45:00
# 50%    26303.500000            2021-12-31 23:30:00
# 75%    39455.250000            2023-07-03 00:15:00
# max    52607.000000            2024-12-31 23:00:00
# std    15186.765818                            NaN
#
#        grid load [MWh] Calculated resolutions  \
# count                            52608.000000
# mean                             55001.226876
# min                              30902.750000
# 25%                              47095.937500
# 50%                              54872.125000
# 75%                              62639.750000
# max                              81319.500000
# std                               9731.240552
#
#        Grid load incl. hydro pumped storage [MWh] Calculated resolutions  \
# ...
